# %% [markdown]
# In python modules and packages help rganize and reuse code.

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np 
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *
sqrt(16)
print(pi)
# Out:
# 3.141592653589793

# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package import maths
reload(maths)
maths.sub(10,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 from package import maths
# ----> 2 reload(maths)
#       3 maths.sub(10,5)
#
# NameError: name 'reload' is not defined
